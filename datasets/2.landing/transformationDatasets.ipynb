# %%
import pandas as pd

df_ladesaeulen = pd.read_csv("/Users/philippusasefaw/team02/datasets/1.raw/Charger/ladesaeulenregister.csv")

df_ladesaeulen.drop(["Kreis/kreisfreie Stadt","Inbetriebnahmedatum", "Public Key1", "Public Key2", "Public Key3", "Public Key4"], axis = 1, inplace = True)

df_ladesaeulen.head(5)
# Out:
#                      Betreiber                 Straße Hausnummer  \
# 0  EnBW mobility+ AG und Co.KG  Emil-von-Behring-Str.          3
# 1  Stadtwerke Brunsbüttel GmbH     Von Humboldt Platz          9
# 2  Stadtwerke Brunsbüttel GmbH         Kaufhausstraße          1
# 3  Stadtwerke Brunsbüttel GmbH     Gustav Meyer Platz          0
# 4  Stadtwerke Brunsbüttel GmbH       Eddelaker Straße      123 d
#
#                          Adresszusatz  Postleitzahl          Ort  \
# 0                                 NaN         22541  Brunsbüttel
# 1                  Bauamt Brunsbüttel         25541  Brunsbüttel
# 2        Edeka Frauen Kundenparkplatz         25541  Brunsbüttel
# 3  Vor dem Tourismus Büro Brunsbüttel         25541  Brunsbüttel
# 4                                 NaN         25541  Brunsbüttel
#
#            Bundesland  Breitengrad  Längengrad  \
# 0  Schleswig-Holstein    53.900750    9.122620
# 1  Schleswig-Holstein    53.897843    9.121495
# 2  Schleswig-Holstein    53.899666    9.126402
# 3  Schleswig-Holstein    53.908717    9.138646
# 4  Schleswig-Holstein    53.906567    9.138991
#
#    Nennleistung Ladeeinrichtung [kW]  Art der Ladeeinrichung  \
# 0                              150.0  Schnellladeeinrichtung
# 1                               44.0   Normalladeeinrichtung
# 2                               44.0   Normalladeeinrichtung
# 3                               44.0   Normalladeeinrichtung
# 4                               44.0   Normalladeeinrichtung
#
#    Anzahl Ladepunkte       Steckertypen1 P1 [kW]       Steckertypen2  P2 [kW]  \
# 0                  2   DC Kupplung Combo     150   DC Kupplung Combo    150.0
# 1                  2  AC Steckdose Typ 2      22  AC Steckdose Typ 2     22.0
# 2                  2  AC Steckdose Typ 2      22  AC Steckdose Typ 2     22.0
# 3                  2  AC Steckdose Typ 2      22  AC Steckdose Typ 2     22.0
# 4                  2  AC Steckdose Typ 2      22  AC Steckdose Typ 2     22.0
#
#   Steckertypen3  P3 [kW] Steckertypen4  P4 [kW]
# 0           NaN      NaN           NaN      NaN
# 1           NaN      NaN           NaN      NaN
# 2           NaN      NaN           NaN      NaN
# 3           NaN      NaN           NaN      NaN
# 4           NaN      NaN           NaN      NaN

# %%
df_ladesaeulen_exc = pd.read_excel("/Users/philippusasefaw/team02/datasets/1.raw/Charger/Ladesaeulenregister.xlsx")

df_ladesaeulen_exc.drop(df_ladesaeulen_exc.index.to_list()[:9], axis = 0, inplace = True)

df_ladesaeulen_exc.rename(columns=df_ladesaeulen_exc.iloc[0], inplace = True)

df_ladesaeulen_exc.drop(9,inplace=True)

df_ladesaeulen_exc.drop(["Kreis/kreisfreie Stadt","Inbetriebnahmedatum", "Public Key1", "Public Key2", "Public Key3", "Public Key4"],axis = 1, inplace = True)

df_ladesaeulen_exc = df_ladesaeulen_exc.reset_index(drop=True)

df_ladesaeulen_exc.head(50)
# Out:
#                                 Betreiber                   Straße Hausnummer  \
# 0                   Albwerk GmbH & Co. KG           Ennabeurer Weg          0
# 1                                 smopi®                 Albstraße         14
# 2                   Albwerk GmbH & Co. KG   Parkplatz Campingplatz          0
# 3            EnBW mobility+ AG und Co.KG               Hauptstraße        91c
# 4                        SWU Energie GmbH               Sterngasse          6
# 5           Physiotherapie im Stadtgarten            Lange Strasse         15
# 6                            Solarcollect           Eichlesstrasse         18
# 7            EnBW mobility+ AG und Co.KG                  Karlstr.         45
# 8            EnBW mobility+ AG und Co.KG                 Flurstück        313
# 9            EnBW mobility+ AG und Co.KG                 Flurstück        313
# 10           EnBW mobility+ AG und Co.KG                 Flurstück        313
# 11           EnBW mobility+ AG und Co.KG                 Flurstück        313
# 12           EnBW mobility+ AG und Co.KG         Parkplatz Burghof          0
# 13           EnBW mobility+ AG und Co.KG                Benzstraße          3
# 14                            EnBW ODR AG         Hindenburgstraße          3
# 15                       SWU Energie GmbH          Hausener Straße         13
# 16                       SWU Energie GmbH             Keplerstraße         16
# 17                       SWU Energie GmbH             Sonnenstraße          4
# 18                       SWU Energie GmbH          Beethovenstraße         40
# 19                       SWU Energie GmbH             Kuftenstraße          4
# 20                       SWU Energie GmbH      Osterstetter Straße         14
# 21                       SWU Energie GmbH                Hallenweg         32
# 22                       SWU Energie GmbH             Herwigstraße         21
# 23                 autohaus Langenau GmbH               Kiesgräble          1
# 24           EnBW mobility+ AG und Co.KG                 Boschstr.          6
# 25                       SWU Energie GmbH  Erhard-Grözinger-Straße         86
# 26          Autohaus Burger GmbH & Co. KG             Ehinger Str.         21
# 27              Tagungszentrum Blaubeuren               Hessenhöfe         33
# 28              Tagungszentrum Blaubeuren               Hessenhöfe         33
# 29           EnBW mobility+ AG und Co.KG    Äußerer Krautgartenweg          6
# 30                       SWU Energie GmbH               Flurstraße          9
# 31                       SWU Energie GmbH      Helfensteinerstraße         12
# 32                       SWU Energie GmbH             Obere Straße          4
# 33                       SWU Energie GmbH               Am Brunnen         11
# 34                       SWU Energie GmbH              Marktstraße         25
# 35                       SWU Energie GmbH           Auf dem Graben         20
# 36                              Lamm Asch              Dorfstrasse         56
# 37                              Lamm Asch              Dorfstrasse         56
# 38                              Lamm Asch              Dorfstrasse         56
# 39                              Lamm Asch          Am Pfarrgarten          23
# 40                  Albwerk GmbH & Co. KG               Marktplatz         14
# 41                          Citywatt GmbH       Treffensbucher Weg         13
# 42                          Citywatt GmbH       Treffensbucher Weg         13
# 43         Jllig Automobile GmbH & Co. KG          Geislinger Str.         49
# 44         Jllig Automobile Gmbh & Co. KG          Geislinger Str.         49
# 45  Häberle Feinmechanik CNC-Technik GmbH   Wilhelm-Maybach-Straße          9
# 46                               ALDI SÜD           Ehinger Straße          5
# 47           EnBW mobility+ AG und Co.KG                 Brühlstr.         21
# 48           EnBW mobility+ AG und Co.KG            Ehinger Straße          0
# 49                       SWU Energie GmbH           Bahnhofstraße           3
#
#                                    Adresszusatz Postleitzahl  \
# 0                                           NaN        72535
# 1                                           NaN        72535
# 2                                           NaN        72589
# 3                                           NaN        73340
# 4                                           NaN        88481
# 5                                           NaN        89129
# 6                                           NaN        89129
# 7                                           NaN        89129
# 8                                           NaN        89129
# 9                                           NaN        89129
# 10                                          NaN        89129
# 11                                          NaN        89129
# 12                                          NaN        89129
# 13                                          NaN        89129
# 14  Volksbank Alb eG Langenau Besucherparkplatz        89129
# 15                                          NaN        89129
# 16                                          NaN        89129
# 17                                          NaN        89129
# 18                                          NaN        89129
# 19                                          NaN        89129
# 20                                          NaN        89129
# 21                                          NaN        89129
# 22                                          NaN        89129
# 23                                          NaN        89129
# 24                                          NaN        89134
# 25                                          NaN        89134
# 26                                          NaN        89143
# 27                                          NaN        89143
# 28                                          NaN        89143
# 29                                          NaN        89143
# 30                                          NaN        89143
# 31                                          NaN        89143
# 32                                          NaN        89143
# 33                                          NaN        89143
# 34                                          NaN        89143
# 35                                          NaN        89143
# 36                                          NaN        89143
# 37                                          NaN        89143
# 38                                          NaN        89143
# 39                                          NaN        89143
# 40                                          NaN        89150
# 41                                          NaN        89150
# 42                                          NaN        89150
# 43                                          NaN        89150
# 44                                          NaN        89150
# 45                                          NaN        89150
# 46                                          NaN        89155
# 47                                          NaN        89155
# 48                                          NaN        89155
# 49                                          NaN        89155
#
#                      Ort         Bundesland Breitengrad Längengrad  \
# 0            Heroldstatt  Baden-Württemberg   48.442398   9.659075
# 1            Heroldstatt  Baden-Württemberg   48.449353   9.672201
# 2             Westerheim  Baden-Württemberg     48.5105      9.609
# 3              Amstetten  Baden-Württemberg   48.578534    9.87484
# 4               Balzheim  Baden-Württemberg   48.179959  10.076977
# 5               Langenau  Baden-Württemberg   48.501099  10.122168
# 6               Langenau  Baden-Württemberg   48.505686  10.138781
# 7               Langenau  Baden-Württemberg   48.500374  10.117366
# 8   Langenau/Seligweiler  Baden-Württemberg   48.456817  10.029649
# 9   Langenau/Seligweiler  Baden-Württemberg   48.456817  10.029649
# 10  Langenau/Seligweiler  Baden-Württemberg   48.456817  10.029649
# 11  Langenau/Seligweiler  Baden-Württemberg   48.456817  10.029649
# 12              Langenau  Baden-Württemberg   48.500057  10.123939
# 13              Langenau  Baden-Württemberg    48.49975   10.13395
# 14              Langenau  Baden-Württemberg   48.498966  10.120978
# 15             Setzingen  Baden-Württemberg   48.538896  10.129616
# 16              Langenau  Baden-Württemberg    48.50509  10.128139
# 17              Langenau  Baden-Württemberg   48.500211  10.121083
# 18              Langenau  Baden-Württemberg   48.493191  10.113215
# 19              Langenau  Baden-Württemberg   48.497369  10.121542
# 20              Langenau  Baden-Württemberg    48.48473  10.061164
# 21              Langenau  Baden-Württemberg   48.474798  10.085579
# 22              Langenau  Baden-Württemberg    48.48524  10.028291
# 23              Langenau  Baden-Württemberg   48.493378  10.108723
# 24             Blaustein  Baden-Württemberg   48.416998   9.918955
# 25             Blaustein  Baden-Württemberg   48.409847   9.940684
# 26            Blaubeuren  Baden-Württemberg   48.403661   9.774676
# 27            Blaubeuren  Baden-Württemberg   48.432935   9.772928
# 28            Blaubeuren  Baden-Württemberg   48.432935   9.772928
# 29            Blaubeuren  Baden-Württemberg   48.408031   9.790154
# 30   Blaubeuren - Seißen  Baden-Württemberg   48.418242   9.748788
# 31  Blaubeuren-Gerhausen  Baden-Württemberg   48.398975   9.805573
# 32   Blaubeuren-Pappelau  Baden-Württemberg   48.369369   9.808528
# 33     Blaubeuren - Asch  Baden-Württemberg   48.437012   9.820351
# 34            Blaubeuren  Baden-Württemberg   48.412767    9.78178
# 35            Blaubeuren  Baden-Württemberg   48.413496     9.8623
# 36            Blaubeuren  Baden-Württemberg   48.439328   9.817808
# 37            Blaubeuren  Baden-Württemberg   48.439271   9.817808
# 38            Blaubeuren  Baden-Württemberg   48.439271   9.818275
# 39            Blaubeuren  Baden-Württemberg    48.43975   9.818356
# 40            Laichingen  Baden-Württemberg    48.48938    9.68649
# 41          Machtolsheim  Baden-Württemberg   48.491529   9.750237
# 42          Machtolsheim  Baden-Württemberg   48.491433   9.749749
# 43            Laichingen  Baden-Württemberg   48.492924   9.702628
# 44            Laichingen  Baden-Württemberg   48.491969   9.697276
# 45            Laichingen  Baden-Württemberg   48.493246   9.710927
# 46                Erbach  Baden-Württemberg   48.327562   9.895613
# 47                Erbach  Baden-Württemberg   48.328599   9.881436
# 48                Erbach  Baden-Württemberg    48.32916    9.89644
# 49                Erbach  Baden-Württemberg   48.325227   9.893881
#
#    Nennleistung Ladeeinrichtung [kW]  Art der Ladeeinrichung  \
# 0                                 22   Normalladeeinrichtung
# 1                                 22   Normalladeeinrichtung
# 2                                 22   Normalladeeinrichtung
# 3                                 98  Schnellladeeinrichtung
# 4                                 22   Normalladeeinrichtung
# 5                                 11   Normalladeeinrichtung
# 6                                 11   Normalladeeinrichtung
# 7                                 30   Normalladeeinrichtung
# 8                                300  Schnellladeeinrichtung
# 9                                300  Schnellladeeinrichtung
# 10                               173  Schnellladeeinrichtung
# 11                               173  Schnellladeeinrichtung
# 12                                30   Normalladeeinrichtung
# 13                               150  Schnellladeeinrichtung
# 14                                44   Normalladeeinrichtung
# 15                                22   Normalladeeinrichtung
# 16                                44   Normalladeeinrichtung
# 17                                44   Normalladeeinrichtung
# 18                                44   Normalladeeinrichtung
# 19                                44   Normalladeeinrichtung
# 20                                44   Normalladeeinrichtung
# 21                                44   Normalladeeinrichtung
# 22                                44   Normalladeeinrichtung
# 23                              39.6   Normalladeeinrichtung
# 24                                30   Normalladeeinrichtung
# 25                                22   Normalladeeinrichtung
# 26                                22   Normalladeeinrichtung
# 27                                11   Normalladeeinrichtung
# 28                                11   Normalladeeinrichtung
# 29                                30   Normalladeeinrichtung
# 30                                22   Normalladeeinrichtung
# 31                                22   Normalladeeinrichtung
# 32                                22   Normalladeeinrichtung
# 33                                22   Normalladeeinrichtung
# 34                                30   Normalladeeinrichtung
# 35                                22   Normalladeeinrichtung
# 36                                22   Normalladeeinrichtung
# 37                                11   Normalladeeinrichtung
# 38                                11   Normalladeeinrichtung
# 39                                11   Normalladeeinrichtung
# 40                                22   Normalladeeinrichtung
# 41                                22   Normalladeeinrichtung
# 42                                22   Normalladeeinrichtung
# 43                                22   Normalladeeinrichtung
# 44                              39.6   Normalladeeinrichtung
# 45                               100  Schnellladeeinrichtung
# 46                                44   Normalladeeinrichtung
# 47                                30   Normalladeeinrichtung
# 48                               150  Schnellladeeinrichtung
# 49                                44   Normalladeeinrichtung
#
#    Anzahl Ladepunkte                  Steckertypen1 P1 [kW]  \
# 0                  2             AC Steckdose Typ 2      22
# 1                  4             AC Steckdose Typ 2      22
# 2                  2             AC Steckdose Typ 2      22
# 3                  2              AC Kupplung Typ 2      43
# 4                  1             AC Steckdose Typ 2      22
# 5                  2             AC Steckdose Typ 2      11
# 6                  2              AC Kupplung Typ 2      11
# 7                  2  AC Steckdose Typ 2, AC Schuko      22
# 8                  2              DC Kupplung Combo     300
# 9                  2              DC Kupplung Combo     300
# 10                 2  DC Kupplung Combo, DC CHAdeMO     150
# 11                 2  DC Kupplung Combo, DC CHAdeMO     150
# 12                 2  AC Steckdose Typ 2, AC Schuko      22
# 13                 2              DC Kupplung Combo     150
# 14                 4              AC Kupplung Typ 2      11
# 15                 1             AC Steckdose Typ 2      22
# 16                 1             AC Steckdose Typ 2      22
# 17                 1             AC Steckdose Typ 2      22
# 18                 1             AC Steckdose Typ 2      22
# 19                 1             AC Steckdose Typ 2      22
# 20                 1             AC Steckdose Typ 2      22
# 21                 1             AC Steckdose Typ 2      22
# 22                 1             AC Steckdose Typ 2      22
# 23                 2              DC Kupplung Combo      22
# 24                 2  AC Steckdose Typ 2, AC Schuko      22
# 25                 2  AC Steckdose Typ 2, AC Schuko      11
# 26                 2              AC Kupplung Typ 2      11
# 27                 1             AC Steckdose Typ 2      11
# 28                 1             AC Steckdose Typ 2      11
# 29                 2  AC Steckdose Typ 2, AC Schuko      22
# 30                 1             AC Steckdose Typ 2      22
# 31                 1             AC Steckdose Typ 2      22
# 32                 1             AC Steckdose Typ 2      22
# 33                 1             AC Steckdose Typ 2      22
# 34                 1             AC Steckdose Typ 2      22
# 35                 1             AC Steckdose Typ 2      11
# 36                 1             AC Steckdose Typ 2      22
# 37                 1             AC Steckdose Typ 2      11
# 38                 1             AC Steckdose Typ 2      11
# 39                 1             AC Steckdose Typ 2      11
# 40                 2             AC Steckdose Typ 2      22
# 41                 2             AC Steckdose Typ 2      22
# 42                 2             AC Steckdose Typ 2      22
# 43                 2             AC Steckdose Typ 2      11
# 44                 2              DC Kupplung Combo      22
# 45                 1              DC Kupplung Combo     100
# 46                 2             AC Steckdose Typ 2      22
# 47                 2  AC Steckdose Typ 2, AC Schuko      22
# 48                 2              DC Kupplung Combo     150
# 49                 1             AC Steckdose Typ 2      22
#
#                     Steckertypen2 P2 [kW]       Steckertypen3 P3 [kW]  \
# 0              AC Steckdose Typ 2      22                 NaN     NaN
# 1              AC Steckdose Typ 2      22  AC Steckdose Typ 2      22
# 2              AC Steckdose Typ 2      22                 NaN     NaN
# 3   DC Kupplung Combo, DC CHAdeMO      50                 NaN     NaN
# 4                             NaN     NaN                 NaN     NaN
# 5                       AC Schuko     3.7                 NaN     NaN
# 6                       AC Schuko     3.7                 NaN     NaN
# 7   AC Steckdose Typ 2, AC Schuko      22                 NaN     NaN
# 8               DC Kupplung Combo     300                 NaN     NaN
# 9               DC Kupplung Combo     300                 NaN     NaN
# 10             AC Steckdose Typ 2      22                 NaN     NaN
# 11             AC Steckdose Typ 2      22                 NaN     NaN
# 12  AC Steckdose Typ 2, AC Schuko      22                 NaN     NaN
# 13              DC Kupplung Combo     150                 NaN     NaN
# 14              AC Kupplung Typ 2      11   AC Kupplung Typ 2      11
# 15                            NaN     NaN                 NaN     NaN
# 16                            NaN     NaN                 NaN     NaN
# 17                            NaN     NaN                 NaN     NaN
# 18                            NaN     NaN                 NaN     NaN
# 19                            NaN     NaN                 NaN     NaN
# 20                            NaN     NaN                 NaN     NaN
# 21                            NaN     NaN                 NaN     NaN
# 22                            NaN     NaN                 NaN     NaN
# 23             AC Steckdose Typ 2      11                 NaN     NaN
# 24  AC Steckdose Typ 2, AC Schuko      22                 NaN     NaN
# 25  AC Steckdose Typ 2, AC Schuko      11                 NaN     NaN
# 26              AC Kupplung Typ 2      11                 NaN     NaN
# 27                            NaN     NaN                 NaN     NaN
# 28                            NaN     NaN                 NaN     NaN
# 29  AC Steckdose Typ 2, AC Schuko      22                 NaN     NaN
# 30                            NaN     NaN                 NaN     NaN
# 31                            NaN     NaN                 NaN     NaN
# 32                            NaN     NaN                 NaN     NaN
# 33                            NaN     NaN                 NaN     NaN
# 34                            NaN     NaN                 NaN     NaN
# 35                            NaN     NaN                 NaN     NaN
# 36                            NaN     NaN                 NaN     NaN
# 37                            NaN     NaN                 NaN     NaN
# 38                            NaN     NaN                 NaN     NaN
# 39                            NaN     NaN                 NaN     NaN
# 40             AC Steckdose Typ 2      22                 NaN     NaN
# 41             AC Steckdose Typ 2      22                 NaN     NaN
# 42             AC Steckdose Typ 2      22                 NaN     NaN
# 43              DC Kupplung Combo      22                 NaN     NaN
# 44             AC Steckdose Typ 2      11                 NaN     NaN
# 45                            NaN     NaN                 NaN     NaN
# 46             AC Steckdose Typ 2      22                 NaN     NaN
# 47  AC Steckdose Typ 2, AC Schuko      22                 NaN     NaN
# 48              DC Kupplung Combo     150                 NaN     NaN
# 49                            NaN     NaN                 NaN     NaN
#
#          Steckertypen4 P4 [kW]
# 0                  NaN     NaN
# 1   AC Steckdose Typ 2      22
# 2                  NaN     NaN
# 3                  NaN     NaN
# 4                  NaN     NaN
# 5                  NaN     NaN
# 6                  NaN     NaN
# 7                  NaN     NaN
# 8                  NaN     NaN
# 9                  NaN     NaN
# 10                 NaN     NaN
# 11                 NaN     NaN
# 12                 NaN     NaN
# 13                 NaN     NaN
# 14   AC Kupplung Typ 2      11
# 15                 NaN     NaN
# 16                 NaN     NaN
# 17                 NaN     NaN
# 18                 NaN     NaN
# 19                 NaN     NaN
# 20                 NaN     NaN
# 21                 NaN     NaN
# 22                 NaN     NaN
# 23                 NaN     NaN
# 24                 NaN     NaN
# 25                 NaN     NaN
# 26                 NaN     NaN
# 27                 NaN     NaN
# 28                 NaN     NaN
# 29                 NaN     NaN
# 30                 NaN     NaN
# 31                 NaN     NaN
# 32                 NaN     NaN
# 33                 NaN     NaN
# 34                 NaN     NaN
# 35                 NaN     NaN
# 36                 NaN     NaN
# 37                 NaN     NaN
# 38                 NaN     NaN
# 39                 NaN     NaN
# 40                 NaN     NaN
# 41                 NaN     NaN
# 42                 NaN     NaN
# 43                 NaN     NaN
# 44                 NaN     NaN
# 45                 NaN     NaN
# 46                 NaN     NaN
# 47                 NaN     NaN
# 48                 NaN     NaN
# 49                 NaN     NaN

# %%
df_prices = pd.read_csv("/Users/philippusasefaw/team02/datasets/Gasstation/price/2023-07-21-prices.csv")

df_prices.drop(["dieselchange","e5change", "e10change"], axis=1, inplace = True)

df_prices.head(10)
# Out:
#                       date                          station_uuid  diesel  \
# 0   2023-07-21 00:00:10+02  b78ace98-5bde-4f84-9820-8abd807e9644   1.639
# 1   2023-07-21 00:00:10+02  ecc1f7d9-6882-435d-83a4-8414bb0d867a   1.579
# 2   2023-07-21 00:00:10+02  9b79ce29-8e4d-433a-895c-09f3eb005a48   1.589
# 3   2023-07-21 00:00:10+02  e9a590a0-ec5f-4e2e-b82f-0379f9ccaecc   1.599
# 4   2023-07-21 00:00:10+02  886841e0-58e7-4454-b03c-6577af7a97e9   1.679
# 5   2023-07-21 00:00:10+02  ef57cb93-3d64-4689-9f78-143818a90127   1.659
# 6   2023-07-21 00:00:10+02  7500eb91-bb2f-490b-b921-edf3ce810934   1.659
# 7   2023-07-21 00:01:24+02  0ed71b80-307e-4653-9bf2-e04f3a545a51   1.639
# 8   2023-07-21 00:01:24+02  1998bec6-b339-4061-9e99-c270be8209d6   1.599
# 9   2023-07-21 00:01:24+02  74a06797-e4ce-40f7-b232-2af50da386f2   1.599
# 10  2023-07-21 00:01:24+02  2cab39da-2920-48e6-bc55-c5a13f4dbc6c   1.639
# 11  2023-07-21 00:01:24+02  105a1954-d44b-408d-b7d2-56f3d44c1c67   1.629
# 12  2023-07-21 00:01:24+02  40d40430-2b76-4fea-9290-ec04583696f8   1.599
# 13  2023-07-21 00:01:24+02  d4a4644c-cd86-42a5-9cfa-ec6c58204312   1.579
# 14  2023-07-21 00:02:10+02  a341cc35-27d8-4cbf-9fc1-e15c5c4f5cf9   1.589
# 15  2023-07-21 00:02:10+02  1ea72b31-4391-454b-9ac0-603ce8c5841b   1.609
# 16  2023-07-21 00:02:10+02  af903128-ecaf-412c-835a-fde57a624255   1.649
# 17  2023-07-21 00:02:10+02  696718ee-703b-4c93-aedc-7055e3376c06   1.548
# 18  2023-07-21 00:02:10+02  74be2779-7bc5-44ef-80e2-18cdbe19b570   1.619
# 19  2023-07-21 00:02:10+02  de1f57df-a69d-416f-a718-ddf20da5da75   1.619
# 20  2023-07-21 00:02:10+02  b9f0f8fb-31c8-468a-ac5d-6e52af6aa0e4   1.629
# 21  2023-07-21 00:02:10+02  2daa7489-283e-4be0-d25c-3e185988dfa4   1.629
# 22  2023-07-21 00:03:29+02  00060988-0064-4444-8888-acdc00000064   1.619
# 23  2023-07-21 00:03:29+02  34285c97-4e35-440b-948d-d4ba77cad74a   1.649
# 24  2023-07-21 00:03:29+02  fb3d413e-0a65-4dae-8176-57548ce9e7c6   1.609
# 25  2023-07-21 00:03:29+02  83a5fb91-e0a9-11ec-a569-005056a27fa7   1.579
# 26  2023-07-21 00:03:29+02  a23ffdb6-4e90-11eb-9a41-005056a2a083   1.629
# 27  2023-07-21 00:03:29+02  79e6e21d-6735-4e41-9958-543a31fb8afb   1.589
# 28  2023-07-21 00:03:29+02  a2380ebc-1b74-4ac0-9db0-9a90512513d6   1.619
# 29  2023-07-21 00:03:29+02  fa8baf41-dba7-42a4-bd9e-7c7676d75c7d   1.639
# 30  2023-07-21 00:04:08+02  3473c53b-6506-4266-8fde-7165f6636888   1.629
# 31  2023-07-21 00:04:08+02  6a346648-5d70-4549-8c58-a6edaec484e7   1.669
# 32  2023-07-21 00:04:08+02  761ff4da-7b94-4bf4-919f-8238418e90cc   1.669
# 33  2023-07-21 00:04:08+02  43b70689-8e74-d079-3137-4b8e45753c85   1.668
# 34  2023-07-21 00:04:08+02  44eb291f-06e6-4d55-8ad3-9d98ba21011f   1.559
# 35  2023-07-21 00:04:08+02  7f6ec850-f413-46b9-992d-0cb2671e25dd   1.599
# 36  2023-07-21 00:04:08+02  23be61cd-3dda-c1f3-67c1-a372ee3a2601   1.839
# 37  2023-07-21 00:04:08+02  00062462-a0eb-4444-8888-acdc00000001   1.679
# 38  2023-07-21 00:04:08+02  42c1c4f5-d8ac-4570-371c-1189205ac793   1.649
# 39  2023-07-21 00:05:24+02  39254885-aacf-4d3b-5909-d7db06222647   1.609
# 40  2023-07-21 00:05:24+02  92e793a8-a3c3-4d7c-2ecc-bf4e8469b708   1.609
# 41  2023-07-21 00:05:24+02  51d4b70b-a095-1aa0-e100-80009459e03a   1.589
# 42  2023-07-21 00:06:06+02  51d4b4bf-a095-1aa0-e100-80009459e03a   1.609
# 43  2023-07-21 00:06:06+02  51d4b52e-a095-1aa0-e100-80009459e03a   1.589
# 44  2023-07-21 00:06:06+02  400cfe48-f7b7-4312-b87d-30922e9d3113   1.619
# 45  2023-07-21 00:06:06+02  74688fe5-3063-47c1-aa36-27d5b4155102   1.629
# 46  2023-07-21 00:08:09+02  258c4cf6-a209-4b6c-e79b-fc28bd47d4a3   1.619
# 47  2023-07-21 00:08:09+02  957f48fb-7efb-47cf-ed1e-8df129be0c40   1.589
# 48  2023-07-21 00:08:09+02  34e7996b-faf2-4ff4-6afa-f376b0164e13   1.599
# 49  2023-07-21 00:08:09+02  6311a058-298f-428b-a4a0-2dbd2c2fb265   1.559
#
#        e5    e10
# 0   1.929  1.869
# 1   1.899  1.759
# 2   1.829  1.769
# 3   1.849  1.789
# 4   1.859  1.799
# 5   1.909  1.849
# 6   1.949  1.889
# 7   1.899  1.839
# 8   1.799  1.739
# 9   1.819  1.779
# 10  1.829  1.769
# 11  1.859  1.799
# 12  1.849  0.000
# 13  1.789  1.729
# 14  1.849  1.789
# 15  0.000  0.000
# 16  1.849  1.789
# 17  1.818  1.768
# 18  1.849  1.789
# 19  1.869  0.000
# 20  1.859  1.799
# 21  0.000  0.000
# 22  1.829  1.779
# 23  1.859  1.799
# 24  1.769  1.729
# 25  1.839  1.779
# 26  1.719  1.689
# 27  1.789  1.729
# 28  1.779  1.719
# 29  1.869  1.809
# 30  1.869  1.809
# 31  1.889  1.829
# 32  1.859  1.799
# 33  1.888  1.828
# 34  1.799  1.739
# 35  1.799  1.739
# 36  2.039  1.989
# 37  1.909  0.000
# 38  1.879  1.819
# 39  1.799  1.739
# 40  1.799  1.739
# 41  1.799  1.739
# 42  1.819  1.759
# 43  1.819  1.759
# 44  1.779  1.729
# 45  1.839  1.789
# 46  1.849  1.789
# 47  1.799  1.739
# 48  1.749  1.689
# 49  1.819  1.769

# %%
df_stations = pd.read_csv("/Users/philippusasefaw/team02/datasets/Gasstation/price/2023-07-21-stations.csv")

df_stations.drop(["first_active", "openingtimes_json"], axis = 1, inplace = True)

df_stations.head(10)
# Out:
#                                    uuid                      name  \
# 0  44e2bdb7-13e3-4156-8576-8326cdd20459            bft Tankstelle
# 1  0e18d0d3-ed38-4e7f-a18e-507a78ad901d   OIL! Tankstelle München
# 2  ad812258-94e7-473d-aa80-d392f7532218    bft Bonn-Bad Godesberg
# 3  eae30bf0-21dd-48cd-a369-03234fcd57df     Tankcenter Osnabrueck
# 4  eae15ca5-73c6-4989-bcbe-026ed0dcdecc             Q1 Tankstelle
# 5  18a9efa8-3fd2-4366-928f-f4c5492ec86e           Aral Tankstelle
# 6  ead7db06-0364-440c-ae9f-59ca0d503a79            Ingo Bornemann
# 7  0ac68306-51f5-46f8-84ef-cc4def6a1682      TotalEnergies Jarmen
# 8  eac6979c-a96e-46f0-8522-a7da9bf87100  Shell Heilbronn Allee 80
# 9  eabe4d46-f7c1-4192-92c5-4b5e02bd339f           Esso Tankstelle
#
#            brand                 street house_number post_code  \
# 0            NaN         Schellengasse            53     36304
# 1           OIL!    Eversbuschstraße 33          NaN     80999
# 2            bft      Godesberger Allee           55     53175
# 3     Tankcenter         Wersener Str.            70     49090
# 4             Q1           Am Töpferweg            1     06917
# 5           ARAL  Wolfenbütteler Straße           59     38268
# 6      Westfalen                 Loburg           58     48346
# 7  TotalEnergies           Klinkenberg            28     17126
# 8          Shell                  Allee           80     74072
# 9           ESSO      SITTARDER STR. 59                  52538
#
#               city   latitude  longitude
# 0          Alsfeld  50.752009   9.279039
# 1          München  48.180700  11.460900
# 2             Bonn  50.695100   7.142760
# 3       Osnabrueck  52.296679   8.000490
# 4  Jessen (Elster)  51.777900  13.142500
# 5          Lengede  52.186603  10.339051
# 6        Ostbevern  52.036540   7.858580
# 7           Jarmen  53.921807  13.347471
# 8        Heilbronn  49.145767   9.223725
# 9         SELFKANT  51.014555   5.902493

# %%
df_zulassung_bundesland = pd.read_excel("/Users/philippusasefaw/team02/datasets/fz14_2022.xlsx", sheet_name="FZ 14.1")

df_zulassung_bundesland = df_zulassung_bundesland.drop([0,1,2,3,4,5,7,8])
df_zulassung_bundesland = df_zulassung_bundesland.rename(columns= df_zulassung_bundesland.iloc[0])
df_zulassung_bundesland = df_zulassung_bundesland.drop(df_zulassung_bundesland.columns[[0,5,8,9,10,11,12,13,15]], axis = 1)
df_zulassung_bundesland = df_zulassung_bundesland.reset_index(drop = True)
df_zulassung_bundesland["Land"] = df_zulassung_bundesland.ffill(inplace = True)
df_zulassung_bundesland = df_zulassung_bundesland.drop(df_zulassung_bundesland[df_zulassung_bundesland["Kraftstoffart"]!="Elektro (BEV)"].index, axis=0)
df_zulassung_bundesland = df_zulassung_bundesland.drop(df_zulassung_bundesland.columns[[0,9]], axis = 1)
df_zulassung_bundesland = df_zulassung_bundesland.reset_index(drop = True)
df_zulassung_bundesland.rename(columns={"Kraftomni-\nbusse": "Kraftomnibusse"}, inplace=True)

df_zulassung_bundesland.head(10)
# Out:
#                     Land   Kraftstoffart Krafträder Personenkraftwagen  \
# 0       Baden-Württemberg  Elektro (BEV)       3536              71328
# 1                  Bayern  Elektro (BEV)       4866              95766
# 2                  Berlin  Elektro (BEV)       2046              10479
# 3             Brandenburg  Elektro (BEV)        576               8164
# 4                  Bremen  Elektro (BEV)         72               2459
# 5                 Hamburg  Elektro (BEV)        305               9149
# 6                  Hessen  Elektro (BEV)       6049              47846
# 7  Mecklenburg-Vorpommern  Elektro (BEV)        561               3883
# 8           Niedersachsen  Elektro (BEV)       2079              47860
# 9     Nordrhein-Westfalen  Elektro (BEV)       4948             104233
#
#   Kraftomnibusse Lastkraftwagen Zugmaschinen Sonstige Kfz
# 0             38           1473           25          133
# 1             71           1868           21          147
# 2              1            683            9            8
# 3              1            267            5            3
# 4             15             58            1           22
# 5             52            361            -           14
# 6             67           1199            4          100
# 7             36            184            2            -
# 8            103           1331           10          665
# 9             77           8655           53          313

# %%
df_zulassung_kraftstoffart = pd.read_excel("/Users/philippusasefaw/team02/datasets/fz14_2022.xlsx", sheet_name="FZ 14.2.1")

df_zulassung_kraftstoffart.drop([0,1,2,3,4,5,7], inplace=True)
df_zulassung_kraftstoffart.rename(columns = df_zulassung_kraftstoffart.iloc[0], inplace = True)
df_zulassung_kraftstoffart.drop(6, inplace = True)
df_zulassung_kraftstoffart.rename(columns = {"Jahr \n\n": "Jahr", "Elektro\n(BEV)" : "Elektro"}, inplace = True)
df_zulassung_kraftstoffart = df_zulassung_kraftstoffart[["Jahr", "Elektro"]].reset_index(drop= True)
df_zulassung_kraftstoffart.drop(df_zulassung_kraftstoffart.index.to_list()[18:], axis = 0, inplace = True)
df_zulassung_kraftstoffart.tail(50)
# Out:
#     Jahr Elektro
# 0   2005      47
# 1   2006      19
# 2   2007       8
# 3   2008      36
# 4   2009     162
# 5   2010     541
# 6   2011    2154
# 7   2012    2956
# 8   2013    6051
# 9   2014    8522
# 10  2015   12363
# 11  2016   11410
# 12  2017   25056
# 13  2018   36062
# 14  2019   63281
# 15  2020  194163
# 16  2021  355961
# 17  2022  470559

# %%
df_zulassung_marken = pd.read_excel("/Users/philippusasefaw/team02/datasets/fz14_2022.xlsx", sheet_name="FZ 14.5")
df_zulassung_marken.drop(df_zulassung_marken.index.to_list()[:6], axis = 0, inplace = True)
df_zulassung_marken.rename(columns= df_zulassung_marken.iloc[0], inplace = True)
df_zulassung_marken = df_zulassung_marken[["Marke", "Elektro\n(BEV)"]]
df_zulassung_marken.drop(df_zulassung_marken.index.to_list()[:2], axis = 0, inplace = True)
df_zulassung_marken = df_zulassung_marken.reset_index(drop=True)
df_zulassung_marken.rename(columns = {"Elektro\n(BEV)": "Elektro"}, inplace = True)
df_zulassung_marken.drop(df_zulassung_marken.index.to_list()[56:], axis = 0, inplace = True)
df_zulassung_marken.tail(50)
# Out:
#           Marke Elektro
# 6      CADILLAC       -
# 7       CITROEN    4694
# 8         DACIA   14369
# 9            DS     524
# 10      FERRARI       -
# 11         FIAT   29911
# 12         FORD    5790
# 13          GWM      15
# 14        HONDA     677
# 15      HYUNDAI   32877
# 16        IVECO       -
# 17       JAGUAR     390
# 18         JEEP       -
# 19          KIA   11456
# 20         LADA       -
# 21  LAMBORGHINI       -
# 22   LAND ROVER       -
# 23         LEVC       -
# 24        LEXUS      17
# 25        LOTUS       -
# 26    LYNK & CO       4
# 27          MAN      10
# 28     MASERATI       -
# 29        MAZDA    1815
# 30     MERCEDES   25182
# 31     MG ROEWE    8774
# 32     MG ROVER       -
# 33         MINI   11744
# 34   MITSUBISHI       -
# 35       MORGAN       -
# 36          NIO     498
# 37       NISSAN    4331
# 38         OPEL   29297
# 39      PEUGEOT   15371
# 40     POLESTAR    6984
# 41      PORSCHE    4789
# 42      RENAULT   27858
# 43  ROLLS ROYCE      42
# 44         SEAT   12595
# 45        SKODA   12194
# 46        SMART   12190
# 47    SSANGYONG     187
# 48       SUBARU     117
# 49       SUZUKI       -
# 50        TESLA   69963
# 51       TOYOTA     840
# 52        VOLVO    5212
# 53           VW   63206
# 54     SONSTIGE    4844
# 55    INSGESAMT  470559

# %%
df_zulassung_segment = pd.read_excel("/Users/philippusasefaw/team02/datasets/fz14_2022.xlsx", sheet_name="FZ 14.6")
df_zulassung_segment.drop(df_zulassung_segment.index.to_list()[:6], axis = 0, inplace = True)
df_zulassung_segment.rename(columns = df_zulassung_segment.iloc[0], inplace = True)
df_zulassung_segment = df_zulassung_segment[["Segment", "Modellreihe", "Elektro\n(BEV)"]]
df_zulassung_segment.rename(columns = {"Elektro\n(BEV)": "Elektro"}, inplace=True)
df_zulassung_segment.drop([6,7], axis=0, inplace=True)
df_zulassung_segment = df_zulassung_segment.reset_index(drop=True)
df_zulassung_segment["Segment"].ffill(inplace=True)
df_zulassung_segment.rename(columns={"Modellreihe": "Modell"}, inplace=True)
df_zulassung_segment.drop(df_zulassung_segment.index.to_list()[364:], axis = 0, inplace = True)
df_zulassung_segment.tail(50)
# Out:
#                       Segment                 Modell Elektro
# 314                 UTILITIES   FORD TRANSIT COURIER       -
# 315                 UTILITIES  FORD TRANSIT, TOURNEO       -
# 316                 UTILITIES         HYUNDAI STARIA       -
# 317                 UTILITIES                MAN TGE      10
# 318                 UTILITIES         MERCEDES CITAN      20
# 319                 UTILITIES      MERCEDES SPRINTER       1
# 320                 UTILITIES          MERCEDES VITO     452
# 321                 UTILITIES           NISSAN NV200      64
# 322                 UTILITIES           NISSAN NV300       -
# 323                 UTILITIES       NISSAN PRIMASTAR       -
# 324                 UTILITIES        NISSAN TOWNSTAR       1
# 325                 UTILITIES             OPEL COMBO     817
# 326                 UTILITIES       OPEL ZAFIRA LIFE     584
# 327                 UTILITIES          PEUGEOT BOXER       -
# 328                 UTILITIES         PEUGEOT EXPERT     119
# 329                 UTILITIES         PEUGEOT RIFTER     424
# 330                 UTILITIES         RENAULT KANGOO       -
# 331                 UTILITIES         RENAULT MASTER       -
# 332                 UTILITIES         RENAULT TRAFIC       -
# 333                 UTILITIES          TOYOTA PROACE     186
# 334                 UTILITIES               VW CADDY       -
# 335                 UTILITIES             VW CRAFTER      33
# 336                 UTILITIES            VW ID. BUZZ    1367
# 337                 UTILITIES         VW TRANSPORTER     100
# 338                 UTILITIES               SONSTIGE       -
# 339        UTILITIES ZUSAMMEN                    NaN    5137
# 340                WOHNMOBILE         CITROEN JUMPER       -
# 341                WOHNMOBILE          CITROEN JUMPY      38
# 342                WOHNMOBILE            FIAT DUCATO       -
# 343                WOHNMOBILE  FORD TRANSIT, TOURNEO       -
# 344                WOHNMOBILE            IVECO DAILY       -
# 345                WOHNMOBILE        IVECO EUROCARGO       -
# 346                WOHNMOBILE                MAN TGE       -
# 347                WOHNMOBILE                MAN TGM       -
# 348                WOHNMOBILE      MERCEDES SPRINTER       1
# 349                WOHNMOBILE      MERCEDES V-KLASSE       -
# 350                WOHNMOBILE          MERCEDES VITO       -
# 351                WOHNMOBILE       OPEL ZAFIRA LIFE       -
# 352                WOHNMOBILE          PEUGEOT BOXER       -
# 353                WOHNMOBILE         PEUGEOT EXPERT       -
# 354                WOHNMOBILE         RENAULT MASTER       -
# 355                WOHNMOBILE         RENAULT TRAFIC       -
# 356                WOHNMOBILE          TOYOTA PROACE       -
# 357                WOHNMOBILE               VW CADDY       -
# 358                WOHNMOBILE             VW CRAFTER       -
# 359                WOHNMOBILE         VW TRANSPORTER       -
# 360                WOHNMOBILE               SONSTIGE       1
# 361       WOHNMOBILE ZUSAMMEN                    NaN      40
# 362                  SONSTIGE                    NaN    7144
# 363  NEUZULASSUNGEN INSGESAMT                    NaN  470559

# %%
df_zulassung_modell = pd.read_excel("/Users/philippusasefaw/team02/datasets/fz14_2022.xlsx", sheet_name="FZ 14.7")
df_zulassung_modell.drop(df_zulassung_modell.index.to_list()[:6], inplace = True)
df_zulassung_modell.rename(columns=df_zulassung_modell.iloc[0], inplace = True)
df_zulassung_modell.drop([6,7], axis=0, inplace = True)
df_zulassung_modell = df_zulassung_modell[["Marke/Modellreihe", "Insgesamt"]].reset_index(drop=True)
df_zulassung_modell.rename(columns={"Marke/Modellreihe": "Modell"}, inplace=True)
df_zulassung_modell.drop(df_zulassung_modell.index.to_list()[81:], inplace = True)
df_zulassung_modell.tail(50)
# Out:
#                Modell Insgesamt
# 31       MERCEDES GLB      6111
# 32  MERCEDES GLK, GLC      4328
# 33  MERCEDES S-KLASSE      2717
# 34  MERCEDES V-KLASSE      1391
# 35      MERCEDES VITO       452
# 36         MG ROEWE 4      1769
# 37         MG ROEWE 5      2738
# 38    MG ROEWE MARVEL      1316
# 39        MG ROEWE ZS      2951
# 40          MINI MINI     11744
# 41       NISSAN ARIYA       652
# 42        NISSAN LEAF      3593
# 43       NISSAN NV200        64
# 44         OPEL COMBO       817
# 45         OPEL CORSA     14979
# 46         OPEL MOKKA     12916
# 47   OPEL ZAFIRA LIFE       584
# 48        PEUGEOT 208      9403
# 49       PEUGEOT 2008      5425
# 50     PEUGEOT EXPERT       119
# 51     PEUGEOT RIFTER       424
# 52         POLESTAR 2      6984
# 53     PORSCHE TAYCAN      4534
# 54     RENAULT MEGANE      8490
# 55     RENAULT TWINGO      8833
# 56        RENAULT ZOE     10535
# 57          SEAT BORN     12564
# 58           SEAT MII        29
# 59        SKODA ENYAQ     12184
# 60            SMART 1       248
# 61      SMART FORFOUR      2242
# 62       SMART FORTWO      9700
# 63  SSANGYONG KORANDO       186
# 64    SUBARU SOLTERRA       115
# 65      TESLA MODEL 3     33841
# 66      TESLA MODEL S       448
# 67      TESLA MODEL X       248
# 68      TESLA MODEL Y     35426
# 69         TOYOTA BZ4       654
# 70      TOYOTA PROACE       186
# 71          VOLVO C40      2009
# 72         VOLVO XC40      3203
# 73         VW CRAFTER        33
# 74        VW ID. BUZZ      1367
# 75            VW ID.3     23286
# 76      VW ID.4, ID.5     24847
# 77     VW TRANSPORTER       100
# 78              VW UP     13238
# 79           SONSTIGE      7202
# 80          INSGESAMT    470559
