# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn

# %%
df_ladesaeulen = pd.read_csv("/Users/takomon/Documents/IT/TechLabs/team2/team02/datasets/1.raw/Charger/ladesaeulenregister.csv")
display(df_ladesaeulen)
# Out:
#                                       Betreiber                  Straße  \
# 0                   EnBW mobility+ AG und Co.KG   Emil-von-Behring-Str.
# 1                   Stadtwerke Brunsbüttel GmbH      Von Humboldt Platz
# 2                   Stadtwerke Brunsbüttel GmbH          Kaufhausstraße
# 3                   Stadtwerke Brunsbüttel GmbH      Gustav Meyer Platz
# 4                   Stadtwerke Brunsbüttel GmbH        Eddelaker Straße
# ...                                         ...                     ...
# 1672  Hotel Prisma Betriebs-und Management GmbH    Max-Johannsen Brücke
# 1673                                       Lidl             Fehrmanstr.
# 1674                                EWE Go GmbH         Altonaer Straße
# 1675                           Mer Germany GmbH         Altonaer Straße
# 1676                  E.ON Drive Infrastructure  Aalbek West an der A19
#
#      Hausnummer                        Adresszusatz  Postleitzahl  \
# ...

# %%
# Here is the code for export the edit dataframe into a new csv file
# please add your local location of the folder where you want to store the data therefore use this guide:
# raw = is stored Data from the source
# landing = stored Data that we have edit ( do not edit and directly from the source folder!)
# gold = here we stored the final DF that we gonna use for DS and Plotting (combination of landing code)

# and please store your code under the folder "code"
output_file_path = "/Users/takomon/Documents/IT/TechLabs/team2/team02/datasets/2.landing/ladesaeulen.csv"

df_ladesaeulen.to_csv(output_file_path, index=False)
